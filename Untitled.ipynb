# %%
pip install -r requirements.txt
# Out:
# ...
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#       --------------------------------------- 0.3/15.8 MB ? eta -:--:--
#      - ------------------------------------- 0.5/15.8 MB 584.8 kB/s eta 0:00:27
#      - ------------------------------------- 0.5/15.8 MB 584.8 kB/s eta 0:00:27
#      - ------------------------------------- 0.5/15.8 MB 584.8 kB/s eta 0:00:27
#      - ------------------------------------- 0.8/15.8 MB 514.8 kB/s eta 0:00:30
#      - ------------------------------------- 0.8/15.8 MB 514.8 kB/s eta 0:00:30
#      -- ------------------------------------ 1.0/15.8 MB 548.3 kB/s eta 0:00:27
# ...

# %%
pip install Flask==3.0.3 flask-cors==4.0.1 joblib==1.4.2 scikit-learn==1.4.2 textblob==0.18.0.post0 nltk==3.8.1 pandas==2.2.2 matplotlib==3.8.4 seaborn==0.13.2 wordcloud==1.9.3
# Out:
# ...
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached Flask_Cors-4.0.1-py2.py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#      ---------------------------------------- 0.0/7.8 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#      - -------------------------------------- 0.3/7.8 MB ? eta -:--:--
#      -- ------------------------------------- 0.5/7.8 MB 698.5 kB/s eta 0:00:11
#      ---- ----------------------------------- 0.8/7.8 MB 976.1 kB/s eta 0:00:08
#      ----- ---------------------------------- 1.0/7.8 MB 1.2 MB/s eta 0:00:06
#      -------- ------------------------------- 1.6/7.8 MB 1.3 MB/s eta 0:00:05
#      --------- ------------------------------ 1.8/7.8 MB 1.3 MB/s eta 0:00:05
#      ---------- ----------------------------- 2.1/7.8 MB 1.3 MB/s eta 0:00:05
#      ------------ --------------------------- 2.4/7.8 MB 1.3 MB/s eta 0:00:05
# ...

# %%
pip install flask-cors wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
python flask_app.py
# Out:
#   Cell In[4], line 1
#     python flask_app.py
#            ^
# SyntaxError: invalid syntax

# %%
python flask_app.py
# Out:
#   Cell In[5], line 1
#     python flask_app.py
#            ^
# SyntaxError: invalid syntax
