# %% [markdown]
# # Run the Movie Sentiment Analysis Web App
#
# Run the single cell below. When you see `Running on http://127.0.0.1:5000`,
# open that link in your browser.
#
# To **stop** the server: Kernel → Interrupt (or the ■ button).

# %%
import os

# Point this at the folder that contains flask_app.py.
# If this notebook lives in the 'notebooks/' folder, the project root is one level up:
PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
os.chdir(PROJECT_ROOT)
print('Working directory:', os.getcwd())

# Import the launcher. use_reloader=False makes Flask work inside Jupyter.
from flask_app import run_app

# Start the server -> then open http://127.0.0.1:5000
run_app(host='127.0.0.1', port=5000)
